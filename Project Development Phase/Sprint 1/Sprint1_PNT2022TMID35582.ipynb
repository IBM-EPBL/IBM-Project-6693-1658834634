# %% [markdown]
# Date        : 14 November 2022
# Team ID     : PNT2022TMID35582
# Project Name: University Admit Eligibility Predictor

# %% [markdown]
# Sprint - 1

# %% [markdown]
# Data Preprocessing

# %% [markdown]
# 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# 2. Reading the dataset

# %%
data = pd.read_csv('Admission_Predict.csv')

# %% [markdown]
# 3. Analyse the data

# %%
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
data.tail()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95

# %%
print('Shape of dataset: ',data.shape)
print('Rows in the dataset    : ',data.shape[0])
print('Columns in the dataset : ',data.shape[1])
# Out:
# Shape of dataset:  (400, 9)
# Rows in the dataset    :  400
# Columns in the dataset :  9

# %% [markdown]
# 4. Descriptive Statistics

# %%
data.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
data.skew()
# Out:
# Serial No.           0.000000
# GRE Score           -0.062893
# TOEFL Score          0.057216
# University Rating    0.171260
# SOP                 -0.275761
# LOR                 -0.106991
# CGPA                -0.065991
# Research            -0.191582
# Chance of Admit     -0.353448
# dtype: float64

# %%
data.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %% [markdown]
# 5. Working with missing values

# %%
print("Looking for missing values:")
data.isnull().any()
# Out:
# Looking for missing values:
# Serial No.           False
# GRE Score            False
# TOEFL Score          False
# University Rating    False
# SOP                  False
# LOR                  False
# CGPA                 False
# Research             False
# Chance of Admit      False
# dtype: bool

# %%
data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data.drop('Serial No.', inplace=True, axis=1)

# %%
data.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP        LOR   \
# count  400.000000   400.000000         400.000000  400.000000  400.000000
# mean   316.807500   107.410000           3.087500    3.400000    3.452500
# std     11.473646     6.069514           1.143728    1.006869    0.898478
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance of Admit
# count  400.000000  400.000000        400.000000
# mean     8.598925    0.547500          0.724350
# std      0.596317    0.498362          0.142609
# min      6.800000    0.000000          0.340000
# 25%      8.170000    0.000000          0.640000
# ...

# %%
data.isnull().sum()
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# 6. Check for categorical columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GRE Score          400 non-null    int64
#  1   TOEFL Score        400 non-null    int64
#  2   University Rating  400 non-null    int64
#  3   SOP                400 non-null    float64
#  4   LOR                400 non-null    float64
#  5   CGPA               400 non-null    float64
#  6   Research           400 non-null    int64
#  7   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 25.1 KB

# %%
data.dtypes
# Out:
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %% [markdown]
# 7. Data Visualization

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
sns.displot(x=data["GRE Score"], kde=True, color='green')
plt.title("GRE score distribution");

# %%
# Observation for GRE Score: score is distributed in the range of 290 to 340 
# Peaks are observed between 310 to 330 indicating most applicants have scored in this range

# %%
sns.displot(x=data["TOEFL Score"], kde=True, color='blue')
plt.title("TOEFL score distribution");

# %%
# Observation for TOFEL score: TOEFL scores are distributed in the range of 90 to 120
# A good number of applicants have scored in between 100 to 115

# %%
sns.countplot(x=data["University Rating"]);
plt.title("Number of Universities for each star rating by applicants");

# %%
# Observatin on university rating : close to 130 applicants have marked their univeristy as 3 star 
# 1 star is given by only 30 applicants which is lowest
# 3 stars are followed by 2 stars for universities

# %%
sns.displot(x=data["SOP"], kde=True, color='purple');
plt.title("Distribution for ratings on SOP");

# %%
# Observation for statement of purpose: most of the applicants have received 3.0 to 4.0 stars in their sop.
# based on the plot, rating distribution can be bucketed in 3 sections 1.0 to 26 as low
# rating and 3.0 to 5.0 as high level of ratings

# %%
data = data.rename(columns={'LOR ':'LOR','Chance of Admit ':'Chance of Admit'})

# %%
sns.displot(x=data["LOR"], kde=True, color='red');
plt.title("Letter of recommendation of applicants Distribution");

# %%
# Observation for LOR: most applicants have a recommendation ratting of 3.0
# a very good number of applicants are having LOR ratting between 3 to 4 inclusive

# %%
sns.displot(x=data["CGPA"], kde=True, color='green');
plt.title("Distribution of CGPA Score");

# %%
# Observation for CGPA: CGPA scores are distributed in range of 6.8 to 9.92 inclusive
# more than 70 applicants have the CGPA of 8.67

# %%
sns.countplot(x=data["Research"]);
plt.title("Research Count");

# %%
# Observation on research : out of 400 applicants approx 240 applicants have opened for research 
# in precentage 64% applicants are chosing for research option

# %% [markdown]
# BIVARIATE ANALYSIS

# %%
cols = data.columns

# %%
features = [i for i in data.columns if i != 'Chance of Admit']
label = 'Chance of Admit'

# %%
features
# Out:
# ['GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR',
#  'CGPA',
#  'Research']

# %%
plt.figure(figsize=(15, 12))
for i in range(len(features)):
    plt.subplot(4, 2, i+1)
    sns.lineplot(x=features[i], y=label, data=data, color='green')
plt.tight_layout()   
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15, 12))
for i in range(len(features)):
    plt.subplot(4, 2, i+1)
    sns.scatterplot(x=features[i], y=label, data=data, color='purple')
plt.tight_layout()   
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15, 12))
for i in range(len(features)):
    plt.subplot(4, 2, i+1)
    sns.boxplot(x=data[features[i]])
plt.tight_layout()

# %%
# Observation based on above box plot:
# The outlier observed in boxplot is that one applicant having : the lowest LOR rating of 1 and the lowest CGPA score is 6.8

# %% [markdown]
# MULTIVARIATE ANALYSIS

# %%
sns.pairplot(data,hue='Research')

# %%
corr_matrix = data.corr()
plt.figure(figsize = (10, 10))
sns.heatmap(corr_matrix,annot=True,fmt='0.2f')
plt.title("Correlation Matrix", fontsize = 20)
plt.show()

# %% [markdown]
# 8. Spliting the dataset

# %%
data.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0
#
#    Chance of Admit
# 0             0.92
# 1             0.76
# 2             0.72
# 3             0.80
# 4             0.65

# %%
x = data.iloc[:,0:7]        #independent variable
y = data['Chance of Admit'] #dependent variable

# %%
x.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research'],
#       dtype='object')

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research
# 0        337          118                  4  4.5  4.5  9.65         1
# 1        324          107                  4  4.0  4.5  8.87         1
# 2        316          104                  3  3.0  3.5  8.00         1
# 3        322          110                  3  3.5  2.5  8.67         1
# 4        314          103                  2  2.0  3.0  8.21         0

# %%
y.head()
# Out:
# 0    0.92
# 1    0.76
# 2    0.72
# 3    0.80
# 4    0.65
# Name: Chance of Admit, dtype: float64

# %%
print('Shape of x:\nRows - ',x.shape[0])
print('Columns - ',x.shape[1])
# Out:
# Shape of x:
# Rows -  400
# Columns -  7

# %%
print('Shape of y:',y.shape)
# Out:
# Shape of y: (400,)

# %% [markdown]
# 8. Scaling the independent variables

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x[x.columns] = scaler.fit_transform(x[x.columns])

# %%
x.head()
# Out:
#    GRE Score  TOEFL Score  University Rating    SOP    LOR      CGPA  Research
# 0       0.94     0.928571               0.75  0.875  0.875  0.913462       1.0
# 1       0.68     0.535714               0.75  0.750  0.875  0.663462       1.0
# 2       0.52     0.428571               0.50  0.500  0.625  0.384615       1.0
# 3       0.64     0.642857               0.50  0.625  0.375  0.599359       1.0
# 4       0.48     0.392857               0.25  0.250  0.500  0.451923       0.0

# %% [markdown]
# 9. Spliting the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
print('x train - shape: ',x_train.shape)
print('x test  - shape: ',x_test.shape)
print('y train - shape: ',y_train.shape)
print('y test  - shape: ',y_test.shape)
# Out:
# x train - shape:  (320, 7)
# x test  - shape:  (80, 7)
# y train - shape:  (320,)
# y test  - shape:  (80,)

# %% [markdown]
# 10. Classification Models

# %%
import numpy as np
cy_train=[1 if chance > 0.82 else 0 for chance in y_train]
cy_train=np.array(cy_train)

cy_test=[1 if chance > 0.82 else 0 for chance in y_test]
cy_test=np.array(cy_test)

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train, cy_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
print('Logistic regression accuracy: {:.3f}'.format(accuracy_score(cy_test, lr.predict(x_test))))
print('---------------------------------------------------')
print(classification_report(cy_test, lr.predict(x_test)))
# Out:
# Logistic regression accuracy: 0.912
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94        54
#            1       0.95      0.77      0.85        26
#
#     accuracy                           0.91        80
#    macro avg       0.93      0.88      0.89        80
# weighted avg       0.92      0.91      0.91        80

# %%
from sklearn.metrics import confusion_matrix

# %%
cy = lr.predict(x_test)
lr_confm = confusion_matrix(cy, cy_test,)
sns.heatmap(lr_confm, annot=True, fmt='.2f',xticklabels = ["Admitted", "Rejected"] , yticklabels = ["Admitted", "Rejected"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Logistic Regression')
plt.show()

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(x_train, cy_train)
# Out:
# RandomForestClassifier()

# %%
print('Random Forest Accuracy: {:.3f}'.format(accuracy_score(cy_test, rf.predict(x_test))))
print('---------------------------------------------------')
print(classification_report(cy_test, rf.predict(x_test)))
# Out:
# Random Forest Accuracy: 0.950
# ---------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        54
#            1       0.96      0.88      0.92        26
#
#     accuracy                           0.95        80
#    macro avg       0.95      0.93      0.94        80
# weighted avg       0.95      0.95      0.95        80

# %%
cy = rf.predict(x_test)
rf_confm = confusion_matrix(cy, cy_test,)
sns.heatmap(rf_confm, annot=True, fmt='.2f',xticklabels = ["Admitted", "Rejected"] , yticklabels = ["Admitted", "Rejected"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Random Forest')
plt.show()

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(x_train, cy_train)
# Out:
# SVC()

# %%
print('Support vector machine accuracy: {:.3f}'.format(accuracy_score(cy_test, svc.predict(x_test))))
print('-----------------------------------------------------')
print(classification_report(cy_test, svc.predict(x_test)))
# Out:
# Support vector machine accuracy: 0.912
# -----------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.90      0.98      0.94        54
#            1       0.95      0.77      0.85        26
#
#     accuracy                           0.91        80
#    macro avg       0.93      0.88      0.89        80
# weighted avg       0.92      0.91      0.91        80

# %%
cy = svc.predict(x_test)
svc_confm = confusion_matrix(cy, cy_test,)
sns.heatmap(svc_confm, annot=True, fmt='.2f',xticklabels = ["Admitted", "Rejected"] , yticklabels = ["Admitted", "Rejected"] )
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Support Vector Machine')
plt.show()

# %%
#Comparing the 3 models used: Linear Regression, Random Forest and SVC.
    #Random Forest model scores higher in accuracy of 95% followed Linear Regression and SVC with accuracy as 91%

# %% [markdown]
# 11. Saving the model

# %%
import pickle

pickle.dump(rf, open("UniversityEligibilityPredictionModel.pkl", 'wb'))

# %% [markdown]
# 12. Loading model for prediction

# %%
model = pickle.load(open("UniversityEligibilityPredictionModel.pkl", 'rb'))

# %%
print("NOTE: ENTER ALL THE VALUES IN FLOATING (98% --> 0.98)")
gre = float(input("Enter your GRE Score:")) 
tofel = float(input("Enter your TOFEL Score:"))
urating = float(input("Enter your University Rating:"))
sop = float(input("Enter your SOP:"))
lor = float(input("Enter your LOR:"))
cgpa = float(input("Enter your CGPA:"))
research = float(input("Enter value for Research:"))
# Out:
# NOTE: ENTER ALL THE VALUES IN FLOATING (98% --> 0.98)
# Enter your GRE Score:0.95
# Enter your TOFEL Score:0.8542
# Enter your University Rating:0.75
# Enter your SOP:0.875
# Enter your LOR:0.875
# Enter your CGPA:0.99
# Enter value for Research:1.0

# %%
features = np.array([[gre,tofel,urating,sop,lor,cgpa,research]])
prediction = model.predict(features)
if(prediction == 1):
    print("Eligible for admission")
else:
    print("Not Eligible for admission")
# Out:
# Eligible for admission

# %%
print("NOTE: ENTER ALL THE VALUES IN FLOATING (98% --> 0.98)")
gre = float(input("Enter your GRE Score:")) 
tofel = float(input("Enter your TOFEL Score:"))
urating = float(input("Enter your University Rating:"))
sop = float(input("Enter your SOP:"))
lor = float(input("Enter your LOR:"))
cgpa = float(input("Enter your CGPA:"))
research = float(input("Enter value for Research:"))
features = np.array([[gre,tofel,urating,sop,lor,cgpa,research]])
prediction = model.predict(features)
if(prediction == 1):
    print("Eligible for admission")
else:
    print("Not Eligible for admission")
# Out:
# NOTE: ENTER ALL THE VALUES IN FLOATING (98% --> 0.98)
# Enter your GRE Score:0.6
# Enter your TOFEL Score:0.432
# Enter your University Rating:0.5
# Enter your SOP:0.54
# Enter your LOR:0.65
# Enter your CGPA:0.91
# Enter value for Research:1.0
# Not Eligible for admission

# %%
print("NOTE: ENTER ALL THE VALUES IN FLOATING (98% --> 0.98)")
gre = float(input("Enter your GRE Score:")) 
tofel = float(input("Enter your TOFEL Score:"))
urating = float(input("Enter your University Rating:"))
sop = float(input("Enter your SOP:"))
lor = float(input("Enter your LOR:"))
cgpa = float(input("Enter your CGPA:"))
research = float(input("Enter value for Research:"))
features = np.array([[gre,tofel,urating,sop,lor,cgpa,research]])
prediction = model.predict(features)
if(prediction == 1):
    print("Eligible for admission")
else:
    print("Not Eligible for admission")
# Out:
# NOTE: ENTER ALL THE VALUES IN FLOATING (98% --> 0.98)
# Enter your GRE Score:0.9
# Enter your TOFEL Score:0.7
# Enter your University Rating:0.6
# Enter your SOP:0.7
# Enter your LOR:0.7
# Enter your CGPA:0.8
# Enter value for Research:0.0
# Eligible for admission
